# %% [markdown]
# # EDA on Lung cancer

# %% [raw]
# 2. Do the EDA on the given dataset: Lung Cancer, and extract some information from this.
#
# Dataset description:
#
# Lung cancer is one of the most prevalent and deadly forms of cancer worldwide, presenting significant challenges in early detection and effective treatment. To aid in the global effort to understand and combat this disease, we are exited to introduce our comprehensive Lung Cancer Dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load the data
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\Lung Cancer.CSV")

# %%
df
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
#data exploration
df.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
df.tail()
# Out:
#          Name   Surname  Age  Smokes  AreaQ  Alkhol  Result
# 54    Ernest   Borgnine   26      13      6       1       0
# 55      Alec   Guinness   77      20      5       4       1
# 56  Charlton     Heston   75      15      3       5       1
# 57   Gregory       Peck   43      30      3       8       1
# 58    Sidney    Poitier   51      25      9       0       0

# %%
df.shape
# Out:
# (59, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     59 non-null     object
#  1   Surname  59 non-null     object
#  2   Age      59 non-null     int64
#  3   Smokes   59 non-null     int64
#  4   AreaQ    59 non-null     int64
#  5   Alkhol   59 non-null     int64
#  6   Result   59 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 3.4+ KB

# %%
#get summary stastistics
df.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %%
#check for missing values
df.isnull()
# Out:
#      Name  Surname    Age  Smokes  AreaQ  Alkhol  Result
# 0   False    False  False   False  False   False   False
# 1   False    False  False   False  False   False   False
# 2   False    False  False   False  False   False   False
# 3   False    False  False   False  False   False   False
# 4   False    False  False   False  False   False   False
# 5   False    False  False   False  False   False   False
# 6   False    False  False   False  False   False   False
# 7   False    False  False   False  False   False   False
# 8   False    False  False   False  False   False   False
# 9   False    False  False   False  False   False   False
# 10  False    False  False   False  False   False   False
# 11  False    False  False   False  False   False   False
# 12  False    False  False   False  False   False   False
# 13  False    False  False   False  False   False   False
# 14  False    False  False   False  False   False   False
# ...

# %%
df.isnull().sum()
# Out:
# Name       0
# Surname    0
# Age        0
# Smokes     0
# AreaQ      0
# Alkhol     0
# Result     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Surname', 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Example DataFrame (replace this with your actual DataFrame)
data = {
    'Age': [25, 32, 47, 51, 62, 33],
    'Salary': [50000, 60000, 80000, 90000, 120000, 75000],
    'Name': ['John', 'Jane', 'Jack', 'Jill', 'Joe', 'Jenny']
}
df = pd.DataFrame(data)
# Plotting distributions
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()
# Selecting only numeric columns
numeric_df = df.select_dtypes(include=[float, int])
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Check for relevant columns
required_columns = ['Name', 'Surname', 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result']
missing_columns = [col for col in required_columns if col not in df.columns]

if not missing_columns:
    print("Dataset contains all required columns.")
else:
    print(f"Missing columns: {missing_columns}")
# Out:
# Missing columns: ['Surname', 'Smokes', 'AreaQ', 'Alkhol', 'Result']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load your dataset
data_path = "C:\\Users\\krish\\OneDrive\\Desktop\\Lung Cancer.CSV"
df = pd.read_csv(data_path)
# Display the first few rows to understand the data
print(df.head())

# Keep only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Check for and handle any missing values
# For simplicity, we'll fill missing values with the mean of the respective columns
numeric_df.fillna(numeric_df.mean(), inplace=True)

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
# Keep only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# %%
numeric_df
# Out:
#     Age  Smokes  AreaQ  Alkhol  Result
# 0    35       3      5       4       1
# 1    27      20      2       5       1
# 2    30       0      5       2       0
# 3    28       0      8       1       0
# 4    68       4      5       6       1
# 5    34       0     10       0       0
# 6    58      15     10       0       0
# 7    22      12      5       2       0
# 8    45       2      6       0       0
# 9    52      18      4       5       1
# 10   33       4      8       0       0
# 11   18      10      6       3       0
# 12   25       2      5       1       0
# 13   28      20      2       8       1
# 14   34      25      4       8       1
# 15   39      18      8       1       0
# 16   42      22      3       5       1
# 17   19      12      8       0       0
# 18   62       5      4       3       1
# 19   73      10      7       6       1
# 20   55      15      1       3       1
# 21   33       8      8       1       0
# 22   22      20      6       2       0
# ...

# %%
numeric_df.fillna(numeric_df.mean(), inplace=True)

# %%
numeric_df
# Out:
#     Age  Smokes  AreaQ  Alkhol  Result
# 0    35       3      5       4       1
# 1    27      20      2       5       1
# 2    30       0      5       2       0
# 3    28       0      8       1       0
# 4    68       4      5       6       1
# 5    34       0     10       0       0
# 6    58      15     10       0       0
# 7    22      12      5       2       0
# 8    45       2      6       0       0
# 9    52      18      4       5       1
# 10   33       4      8       0       0
# 11   18      10      6       3       0
# 12   25       2      5       1       0
# 13   28      20      2       8       1
# 14   34      25      4       8       1
# 15   39      18      8       1       0
# 16   42      22      3       5       1
# 17   19      12      8       0       0
# 18   62       5      4       3       1
# 19   73      10      7       6       1
# 20   55      15      1       3       1
# 21   33       8      8       1       0
# 22   22      20      6       2       0
# ...

# %%
df
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
#display data types to identify non-numeric columns
print(df.dtypes)
# Out:
# Name       object
# Surname    object
# Age         int64
# Smokes      int64
# AreaQ       int64
# Alkhol      int64
# Result      int64
# dtype: object

# %%
#one-hot encoding categorical variables
data = pd.get_dummies(df,drop_first=True)

# %%
data
# Out:
#     Age  Smokes  AreaQ  Alkhol  Result  Name_Alex  Name_Anna  Name_Barbra  \
# 0    35       3      5       4       1      False      False        False
# 1    27      20      2       5       1      False      False        False
# 2    30       0      5       2       0      False      False        False
# 3    28       0      8       1       0       True      False        False
# 4    68       4      5       6       1      False      False        False
# 5    34       0     10       0       0      False      False        False
# 6    58      15     10       0       0      False      False        False
# 7    22      12      5       2       0      False      False        False
# 8    45       2      6       0       0      False      False        False
# 9    52      18      4       5       1      False      False        False
# 10   33       4      8       0       0      False      False        False
# 11   18      10      6       3       0      False      False        False
# ...

# %%
#feature engineering
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
data = pd.DataFrame(scaled_data,columns=data.columns)

# %%
data
# Out:
#          Age    Smokes     AreaQ    Alkhol    Result  Name_Alex  Name_Anna  \
# 0  -0.473821 -1.524356 -0.083321  0.323148  1.052209  -0.131306  -0.131306
# 1  -0.970806  0.623016 -1.312310  0.746830  1.052209  -0.131306  -0.131306
# 2  -0.784437 -1.903304 -0.083321 -0.524218 -0.950382  -0.131306  -0.131306
# 3  -0.908683 -1.903304  1.145668 -0.947900 -0.950382   7.615773  -0.131306
# 4   1.576244 -1.398040 -0.083321  1.170513  1.052209  -0.131306  -0.131306
# 5  -0.535944 -1.903304  1.964994 -1.371583 -0.950382  -0.131306  -0.131306
# 6   0.955012 -0.008564  1.964994 -1.371583 -0.950382  -0.131306  -0.131306
# 7  -1.281422 -0.387512 -0.083321 -0.524218 -0.950382  -0.131306  -0.131306
# 8   0.147411 -1.650672  0.326342 -1.371583 -0.950382  -0.131306  -0.131306
# 9   0.582273  0.370384 -0.492984  0.746830  1.052209  -0.131306  -0.131306
# 10 -0.598067 -1.398040  1.145668 -1.371583 -0.950382  -0.131306  -0.131306
# ...

# %%
scaler
# Out:
# StandardScaler()

# %%
scaled_data
# Out:
# array([[-0.47382073, -1.52435619, -0.08332128, ..., -0.13130643,
#          7.61577311, -0.13130643],
#        [-0.97080603,  0.62301636, -1.31231015, ..., -0.13130643,
#         -0.13130643, -0.13130643],
#        [-0.78443655, -1.90330429, -0.08332128, ..., -0.13130643,
#         -0.13130643, -0.13130643],
#        ...,
#        [ 2.01110578, -0.0085638 , -0.9026472 , ..., -0.13130643,
#         -0.13130643, -0.13130643],
#        [ 0.02316457,  1.88617669, -0.9026472 , ..., -0.13130643,
#         -0.13130643, -0.13130643],
#        [ 0.52014987,  1.25459653,  1.55533055, ..., -0.13130643,
#         -0.13130643, -0.13130643]])

# %% [markdown]
# # Do the EDA on this dataset: presidential election polls 2024 dataset and extract useful information from this:

# %% [markdown]
# # dataset description:
#
# this dataset comprises the results of a nationwide presidential election poll conducted on march 4, 2024. the data offers various insights but does not align with the official election results. you are encouaraged to create your notebooks and derive into the data for futher exploration.

# %%
#load the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")

# %%
df
# Out:
#                     id     sex  age federal_district  \
# 0     07169ed8148ce047    male   18  north caucasian
# 1     0716a4f3354cecdd    male   23  north caucasian
# 2     0716889b304ce79c    male   20            volga
# 3     07168e28b5cce563    male   22     northwestern
# 4     0716a563914ce549    male   21         southern
# ...                ...     ...  ...              ...
# 1595  0716b23c2c0cee3a    male   61          central
# 1596  07168254d14ceb55  female   80            volga
# 1597  071690f34d4ce164  female   76     northwestern
# 1598  0716bfa9c48ce79a  female   74          central
# 1599  07168088318cef88  female   76             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# ...

# %%
print(df.head())
# Out:
#                  id   sex  age federal_district  \
# 0  07169ed8148ce047  male   18  north caucasian
# 1  0716a4f3354cecdd  male   23  north caucasian
# 2  0716889b304ce79c  male   20            volga
# 3  07168e28b5cce563  male   22     northwestern
# 4  0716a563914ce549  male   21         southern
#
#                                    type_of_city    knows_election_date  \
# 0                                       village     named correct date
# 1                                       village     named correct date
# 2         city with population of less than 50k     named correct date
# 3  city with population of 1 million and higher  not sure or no answer
# 4  city with population of 1 million and higher     named correct date
#
#         will_vote candidate      television_usage      internet_usage  \
# 0        not sure     Putin  several times a week  over 4 hours a day
# 1        not sure     Putin      once half a year  over 4 hours a day
# ...

# %%
print(df.tail())
# Out:
#                     id     sex  age federal_district  \
# 1595  0716b23c2c0cee3a    male   61          central
# 1596  07168254d14ceb55  female   80            volga
# 1597  071690f34d4ce164  female   76     northwestern
# 1598  0716bfa9c48ce79a  female   74          central
# 1599  07168088318cef88  female   76             ural
#
#                                type_of_city    knows_election_date  \
# 1595                             settlement     named correct date
# 1596                                village     named correct date
# 1597        city with population of 50-100k     named correct date
# 1598  city with population of less than 50k  not sure or no answer
# 1599                                village     named correct date
#
#            will_vote           candidate      television_usage  \
# 1595   definitely no  will not take part    over 4 hours a day
# 1596      likely yes  struggle to answer  several times a week
# ...

# %%
df.isnull()
# Out:
#          id    sex    age  federal_district  type_of_city  \
# 0     False  False  False             False         False
# 1     False  False  False             False         False
# 2     False  False  False             False         False
# 3     False  False  False             False         False
# 4     False  False  False             False         False
# ...     ...    ...    ...               ...           ...
# 1595  False  False  False             False         False
# 1596  False  False  False             False         False
# 1597  False  False  False             False         False
# 1598  False  False  False             False         False
# 1599  False  False  False             False         False
#
#       knows_election_date  will_vote  candidate  television_usage  \
# 0                   False      False      False             False
# 1                   False      False      False             False
# 2                   False      False      False             False
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
#display basic information about the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1600 non-null   object
#  1   sex                  1600 non-null   object
#  2   age                  1600 non-null   int64
#  3   federal_district     1600 non-null   object
#  4   type_of_city         1600 non-null   object
#  5   knows_election_date  1600 non-null   object
#  6   will_vote            1600 non-null   object
#  7   candidate            1600 non-null   object
#  8   television_usage     1600 non-null   object
#  9   internet_usage       1600 non-null   object
#  10  education            1600 non-null   object
#  11  income               1600 non-null   object
#  12  employment           1600 non-null   object
#  13  job_type             692 non-null    object
#  14  company_type         879 non-null    object
# ...

# %%
#display summary statistics
df.describe()
# Out:
#                age      weight1
# count  1600.000000  1600.000000
# mean     49.936250     1.000000
# std      16.901797     0.327084
# min      18.000000     0.468226
# 25%      37.000000     0.772224
# 50%      49.000000     0.921724
# 75%      64.000000     1.158913
# max      90.000000     2.515072

# %%
#check sum missing values.
df.isnull().sum()
# Out:
# id                       0
# sex                      0
# age                      0
# federal_district         0
# type_of_city             0
# knows_election_date      0
# will_vote                0
# candidate                0
# television_usage         0
# internet_usage           0
# education                0
# income                   0
# employment               0
# job_type               908
# company_type           721
# weight1                  0
# dtype: int64

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#fill missing numeric values with the mean
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].mean())

# %%
numeric_columns
# Out:
# Index(['age', 'weight1'], dtype='object')

# %%
#fill missing categorical values with the mode
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
data = df.select_dtypes(include=[object]).columns
df[data] = df[data].apply(lambda x: x.fillna(x.mode()[0]))

# %%
data
# Out:
# Index(['id', 'sex', 'federal_district', 'type_of_city', 'knows_election_date',
#        'will_vote', 'candidate', 'television_usage', 'internet_usage',
#        'education', 'income', 'employment', 'job_type', 'company_type'],
#       dtype='object')

# %%
#exploratory data analysis
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
plt.figure(figsize=(10,6))
sns.histplot(df['age'],bins = 30,kde = True)
plt.title("distribution of veter ages")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\krish\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#voting preferencies by region
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
print(df.columns)
plt.figure(figsize=(10, 8))
sns.countplot(data=df, x='sex', hue='type_of_city')  
plt.title('Voting Preferences by Region')
plt.xlabel('sex')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.legend(title='type_of_city')
plt.show()
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
print("Unique values in the 'region' column:")
print(df['sex'].unique())

print("Unique values in the 'candidate' column:")
print(df['candidate'].unique())
# Out:
# Unique values in the 'region' column:
# ['male' 'female']
# Unique values in the 'candidate' column:
# ['Putin' 'Davankov' 'will not take part' 'spoilt vote' 'Kharitonov'
#  'struggle to answer' 'Slutskiy']

# %%
#correlation metrics for numeric features
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
print(df.columns)
plt.figure(figsize=(10,8))
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
print(df.columns)
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].mean())
plt.figure(figsize=(10,8))
sns.heatmap(df[numeric_columns].corr(),annot=True, cmap='coolwarm')
plt.title('correlation metrix')
plt.show()
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
#gender distribution among voters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
print(df.columns)
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].mean())
plt.figure(figsize=(10,8))
sns.countplot(data = df,x='sex')
plt.title('gender distribution among voters')
plt.show()
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\krish\\OneDrive\\Desktop\\election2024.csv")
print(df.columns)
numeric_columns = df.select_dtypes(include=[np.number]).columns
df[numeric_columns]=df[numeric_columns].fillna(df[numeric_columns].mean())
plt.figure(figsize=(10,8))
sns.countplot(data = df,x='sex')
plt.title('gender distribution among voters')
plt.xlabel("gender")
plt.ylabel("count")
plt.show()
# Out:
# Index(['id', 'sex', 'age', 'federal_district', 'type_of_city',
#        'knows_election_date', 'will_vote', 'candidate', 'television_usage',
#        'internet_usage', 'education', 'income', 'employment', 'job_type',
#        'company_type', 'weight1'],
#       dtype='object')

# %%
#average age of voters by candidate
avg_age_by_candidate = df.groupby('candidate')['age'].mean().reset_index()
print("\n average age of voters by candidate:")
print(avg_age_by_candidate)
# Out:
#  average age of voters by candidate:
#             candidate        age
# 0            Davankov  39.059701
# 1          Kharitonov  51.507937
# 2               Putin  51.898050
# 3            Slutskiy  45.127273
# 4         spoilt vote  48.518519
# 5  struggle to answer  45.768293
# 6  will not take part  43.718750

# %%
df
# Out:
#                     id     sex  age federal_district  \
# 0     07169ed8148ce047    male   18  north caucasian
# 1     0716a4f3354cecdd    male   23  north caucasian
# 2     0716889b304ce79c    male   20            volga
# 3     07168e28b5cce563    male   22     northwestern
# 4     0716a563914ce549    male   21         southern
# ...                ...     ...  ...              ...
# 1595  0716b23c2c0cee3a    male   61          central
# 1596  07168254d14ceb55  female   80            volga
# 1597  071690f34d4ce164  female   76     northwestern
# 1598  0716bfa9c48ce79a  female   74          central
# 1599  07168088318cef88  female   76             ural
#
#                                       type_of_city    knows_election_date  \
# 0                                          village     named correct date
# 1                                          village     named correct date
# 2            city with population of less than 50k     named correct date
# ...

# %%
#voter turnout by income
turnout_by_income = df['income'].value_counts().reset_index()
turnout_by_income.columns = ['income','voter turnout']
print("\nvoter turnout by income:")
print(turnout_by_income)
# Out:
# voter turnout by income:
#         income  voter turnout
# 0       medium            949
# 1         high            405
# 2          low            149
# 3    very high             48
# 4     very low             34
# 5  hard to say             15
